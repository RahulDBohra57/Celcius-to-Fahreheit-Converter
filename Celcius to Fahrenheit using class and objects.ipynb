# %%
class Temperature:
    
    def __init__(self,temp):
        self.temp = temp

    @property

    def celcius_to_fahrenheit(self):
        fahrenheit = (self.temp * 9/5) + 32
        return fahrenheit
